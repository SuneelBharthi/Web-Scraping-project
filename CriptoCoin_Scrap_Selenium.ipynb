# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

options = Options()

driver = webdriver.Chrome(options = options)
driver.get('https://coinmarketcap.com/')


table = driver.find_element(By.CLASS_NAME,'cmc-table')
table

rows = table.find_elements(By.TAG_NAME,'tr')
rows


for row in rows[1:11]:
    table_data = row.find_elements(By.TAG_NAME, 'td')
    rank       = table_data[1].text
    name       = table_data[2].text
    price      = table_data[3].text
    hour_change= table_data[4].text
    day_change = table_data[5].text
    seven_days = table_data[6].text
    market_cup = table_data[7].text
    volume     = table_data[8].text
    
    print(rank, name,price, hour_change, day_change , seven_days , market_cup ,volume     )
    
    for row in rows[1:]:
    table_data = row.find_elements(By.TAG_NAME, 'td')
    rank       = table_data[1].text
    name       = table_data[2].text
    price      = table_data[3].text
    hour_change= table_data[4].text
    day_change = table_data[5].text
    seven_days = table_data[6].text
    market_cup = table_data[7].text
    volume     = table_data[8].text
    
    print(rank, name,price, hour_change, day_change , seven_days , market_cup ,volume     )

# %%
options = Options()

# %%
driver = webdriver.Chrome(options = options)
driver.get('https://coinmarketcap.com/')

# %%
table = driver.find_element(By.CLASS_NAME,'cmc-table')
table
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.553")>

# %%
rows = table.find_elements(By.TAG_NAME,'tr')
rows
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.554")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.555")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.556")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.557")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.558")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.559")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.560")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.561")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.562")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.563")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.564")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.565")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.566")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.567")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.568")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.569")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.570")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.571")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.572")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.573")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.574")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.575")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.576")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.577")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.578")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.579")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.580")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.581")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.582")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.583")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.584")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.585")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.586")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.587")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.588")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.589")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.590")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.591")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.592")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.593")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.594")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.595")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.596")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.597")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.598")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.599")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.600")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.601")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.602")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.603")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.604")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.605")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.606")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.607")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.608")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.609")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.610")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.611")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.612")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.613")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.614")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.615")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.616")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.617")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.618")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.619")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.620")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.621")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.622")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.623")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.624")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.625")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.626")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.627")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.628")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.629")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.630")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.631")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.632")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.633")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.634")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.635")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.636")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.637")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.638")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.639")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.640")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.641")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.642")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.643")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.644")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.645")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.646")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.647")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.648")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.649")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.650")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.651")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.652")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.653")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e51eff16918544ec06c6450f6e0cec16", element="f.74E3FFAE2FBEDB3432EF54608D864C19.d.9E03088DA6018DD19AB66D82DDDD5D54.e.654")>]

# %% [markdown]
# ### Top 10 Rows Data

# %%
for row in rows[1:11]:
    table_data = row.find_elements(By.TAG_NAME, 'td')
    rank       = table_data[1].text
    name       = table_data[2].text
    price      = table_data[3].text
    hour_change= table_data[4].text
    day_change = table_data[5].text
    seven_days = table_data[6].text
    market_cup = table_data[7].text
    volume     = table_data[8].text
    
    print(rank, name,price, hour_change, day_change , seven_days , market_cup ,volume     )
# Out:
# 1 Bitcoin
# BTC
# Buy $103,964.37 0.22% 0.15% 8.51% $2,065,064,348,585 $45,308,326,182
# 435.73K BTC
# 2 Ethereum
# ETH
# Buy $2,499.09 0.29% 3.51% 35.95% $301,716,112,708 $33,889,300,359
# 13.57M ETH
# 3 Tether
# USDT
# Buy $1.00 0.01% 0.01% 0.00% $149,884,937,490 $99,056,182,845
# 99.07B USDT
# 4 XRP
# XRP
# Buy $2.36 0.31% 1.08% 7.37% $138,695,114,305 $5,069,070,926
# 2.14B XRP
# 5 BNB
# BNB
# Buy $657.65 0.14% 0.51% 10.24% $92,656,479,300 $2,122,429,189
# 3.22M BNB
# 6 Solana
# SOL
# Buy $173.87 0.03% 0.93% 19.43% $90,298,191,081 $4,764,039,245
# 27.43M SOL
# 7 USDC
# USDC
# Buy $0.9996 0.03% 0.03% 0.03% $60,781,674,083 $11,056,444,128
# 11.06B USDC
# 8 Dogecoin
# DOGE
# Buy $0.2321 0.12% 3.01% 32.66% $34,643,592,203 $4,061,223,367
# 17.49B DOGE
# 9 Cardano
# ADA
# Buy $0.7958 0.03% 0.71% 14.15% $28,103,277,811 $1,480,510,880
# 1.86B ADA
# 10 TRON
# TRX
# Buy $0.2618 0.32% 0.49% 5.23% $24,854,533,725 $1,025,190,562
# 3.91B TRX

# %% [markdown]
# ## Now 100 rows data

# %%
for row in rows[1:]:
    table_data = row.find_elements(By.TAG_NAME, 'td')
    rank       = table_data[1].text
    name       = table_data[2].text
    price      = table_data[3].text
    hour_change= table_data[4].text
    day_change = table_data[5].text
    seven_days = table_data[6].text
    market_cup = table_data[7].text
    volume     = table_data[8].text
    
    print(rank, name,price, hour_change, day_change , seven_days , market_cup ,volume     )
# Out:
# 1 Bitcoin
# BTC
# Buy $103,961.82 0.20% 0.14% 8.50% $2,065,013,847,727 $44,600,641,721
# 428.93K BTC
# 2 Ethereum
# ETH
# Buy $2,499.06 0.30% 3.51% 35.95% $301,712,449,381 $34,122,955,808
# 13.66M ETH
# 3 Tether
# USDT
# Buy $1.00 0.01% 0.01% 0.00% $149,884,937,490 $99,056,182,845
# 99.07B USDT
# 4 XRP
# XRP
# Buy $2.36 0.31% 1.08% 7.37% $138,695,114,305 $5,069,070,926
# 2.14B XRP
# 5 BNB
# BNB
# Buy $657.65 0.14% 0.51% 10.24% $92,656,479,300 $2,122,429,189
# 3.22M BNB
# 6 Solana
# SOL
# Buy $173.87 0.03% 0.93% 19.43% $90,298,191,081 $4,764,039,245
# 27.43M SOL
# 7 USDC
# USDC
# Buy $0.9996 0.03% 0.03% 0.03% $60,781,674,083 $11,056,444,128
# 11.06B USDC
# 8 Dogecoin
# DOGE
# Buy $0.2321 0.12% 3.01% 32.66% $34,643,592,203 $4,061,223,367
# 17.49B DOGE
# 9 Cardano
# ADA
# Buy $0.7958 0.03% 0.71% 14.15% $28,103,277,811 $1,480,510,880
# 1.86B ADA
# 10 TRON
# TRX
# Buy $0.2618 0.32% 0.49% 5.23% $24,854,533,725 $1,025,190,562
# 3.91B TRX
# 11 Sui
# SUI
# Buy $3.98 0.65% 0.08% 23.87% $13,302,488,997 $2,419,855,764
# 607.27M SUI
# 12 Chainlink
# LINK
# Buy $16.56 0.08% 0.89% 17.44% $10,884,770,962 $670,789,230
# 40.49M LINK
# 13 Avalanche
# AVAX
# Buy $24.74 0.13% 2.09% 22.72% $10,351,319,035 $681,835,054
# 27.56M AVAX
# 14 Stellar
# XLM
# Buy $0.3049 0.43% 0.33% 12.96% $9,462,420,616 $348,306,344
# 1.14B XLM
# 15 Shiba Inu
# SHIB
# Buy $0.00001589 0.63% 0.59% 22.05% $9,367,047,271 $645,333,959
# 40.60T SHIB
# 16 Hedera
# HBAR
# Buy $0.2065 0.03% 1.36% 14.94% $8,726,185,182 $347,750,298
# 1.68B HBAR
# 17 Toncoin
# TON
# Buy $3.36 0.20% 1.38% 8.74% $8,384,882,133 $239,579,163
# 71.23M TON
# 18 Bitcoin Cash
# BCH
# Buy $412.96 0.39% 2.14% 14.83% $8,204,734,181 $365,115,657
# 885.75K BCH
# 19 Hyperliquid
# HYPE
# Buy $23.98 0.68% 5.21% 16.93% $8,010,770,011 $178,850,816
# 7.44M HYPE
# 20 Polkadot
# DOT
# Buy $5.04 0.18% 0.60% 25.64% $7,955,924,197 $416,499,177
# 82.47M DOT
# 21 Litecoin
# LTC
# Buy $101.30 0.51% 2.66% 17.61% $7,683,282,412 $715,995,611
# 7.07M LTC
# 22 UNUS SED LEO
# LEO
# Buy $8.27 0.09% 4.83% 7.83% $7,641,313,902 $8,459,513
# 1.02M LEO
# 23 Pi
# PI
# Buy $0.9288 1.33% 25.60% 56.92% $6,569,218,794 $557,775,906
# 602.81M PI
# 24 Monero
# XMR
# Buy $322.16 0.03% 2.14% 16.14% $5,942,882,728 $108,927,848
# 337.25K XMR
# 25 Bitget Token
# BGB
# Buy $4.82 1.08% 0.66% 10.45% $5,642,159,512 $358,177,480
# 74.47M BGB
# 26 Pepe
# PEPE
# Buy $0.00001290 0.97% 4.09% 57.94% $5,429,277,679 $2,081,288,897
# 161.05T PEPE
# 27 Dai
# DAI
# Buy $0.9998 0.00% 0.02% 0.01% $5,364,715,753 $17,221,723,177
# 17.22B DAI
# 28 Ethena USDe
# USDe
# Buy $1.00 0.00% 0.00% 0.04% $4,659,343,739 $107,992,220
# 107.98M USDe
# 29 Uniswap
# UNI
# Buy $7.09 0.33% 6.92% 39.67% $4,458,749,988 $486,621,460
# 68.37M UNI
# 30 Bittensor
# TAO
# Buy $450.92 1.05% 0.20% 29.55% $3,952,325,266 $147,822,834
# 328.48K TAO
# 31 NEAR Protocol
# NEAR
# Buy $3.20 0.68% 7.54% 32.99% $3,885,363,665 $339,077,123
# 105.59M NEAR
# 32 Aptos
# APT
# Buy $5.90 0.10% 1.46% 14.67% $3,665,201,994 $294,878,965
# 50.03M APT
# 33 OKB
# OKB
# Buy $55.71 0.20% 0.58% 8.81% $3,342,750,943 $12,001,122
# 215.66K OKB
# 34 Aave
# AAVE
# Buy $219.92 0.58% 0.23% 23.96% $3,324,076,217 $381,477,860
# 1.73M AAVE
# 35 Ondo
# ONDO
# Buy $1.03 0.21% 0.25% 18.49% $3,262,146,789 $293,952,207
# 284.88M ONDO
# 36 Ethereum Classic
# ETC
# Buy $19.81 0.28% 1.12% 20.71% $3,009,272,414 $184,527,841
# 9.31M ETC
# 37 Internet Computer
# ICP
# Buy $5.59 0.28% 1.63% 20.16% $2,981,761,899 $123,022,175
# 21.95M ICP
# 38 Kaspa
# KAS
# Buy $0.1069 1.57% 0.71% 15.96% $2,796,589,955 $123,200,839
# 1.14B KAS
# 39 OFFICIAL TRUMP
# TRUMP
# Buy $13.71 0.90% 5.00% 22.65% $2,743,755,128 $1,506,821,329
# 110.00M TRUMP
# 40 GateToken
# GT
# Buy $22.13 0.02% 0.64% 2.41% $2,720,796,765 $12,826,144
# 579.74K GT
# 41 POL (prev. MATIC)
# POL
# Buy $0.2617 0.60% 0.02% 13.76% $2,727,660,634 $172,142,502
# 659.96M POL
# 42 Render
# RENDER
# Buy $5.18 0.18% 0.67% 15.38% $2,684,412,563 $131,027,187
# 25.35M RENDER
# 43 VeChain
# VET
# Buy $0.03088 0.06% 0.34% 19.87% $2,655,365,343 $79,186,888
# 2.56B VET
# 44 Cronos
# CRO
# Buy $0.09941 0.39% 3.02% 13.05% $2,641,645,097 $42,884,251
# 431.94M CRO
# 45 Mantle
# MNT
# Buy $0.7766 0.20% 0.04% 5.77% $2,613,328,833 $270,525,861
# 348.69M MNT
# 46 Ethena
# ENA
# Buy $0.3956 0.14% 3.75% 35.62% $2,302,755,393 $382,103,485
# 968.39M ENA
# 47 Arbitrum
# ARB
# Buy $0.4644 0.31% 18.22% 45.90% $2,209,164,580 $879,987,180
# 1.89B ARB
# 48 World Liberty Financial USD
# USD1
# Buy $1.00 0.01% 0.04% 0.03% $2,128,351,576 $51,197,830
# 51.20M USD1
# 49 Filecoin
# FIL
# Buy $3.15 0.64% 2.27% 19.26% $2,096,099,635 $204,109,524
# 64.70M FIL
# 50 Algorand
# ALGO
# Buy $0.2417 0.36% 1.38% 18.02% $2,078,742,347 $127,197,731
# 524.80M ALGO
# 51 Artificial Superintelligence Alliance
# FET
# Buy $0.8590 0.73% 0.45% 24.86% $2,053,836,466 $218,970,850
# 252.34M FET
# 52 Cosmos
# ATOM
# Buy $5.20 0.27% 4.20% 24.84% $2,035,784,165 $164,406,699
# 31.56M ATOM
# 53 Celestia
# TIA
# Buy $3.16 0.22% 1.32% 30.42% $1,992,648,046 $209,778,782
# 66.19M TIA
# 54 Worldcoin
# WLD
# Buy $1.26 0.17% 5.83% 33.63% $1,759,142,853 $406,572,930
# 319.76M WLD
# 55 Bonk
# BONK
# Buy $0.00002202 0.18% 2.79% 34.98% $1,742,237,108 $581,722,723
# 26.41T BONK
# 56 Sonic (prev. FTM)
# S
# Buy $0.5882 0.80% 1.45% 9.91% $1,694,126,488 $175,115,192
# 298.16M S
# 57 Jupiter
# JUP
# Buy $0.5530 0.74% 0.76% 30.14% $1,602,680,744 $112,691,887
# 203.95M JUP
# 58 Stacks
# STX
# Buy $0.9995 0.11% 3.69% 26.74% $1,524,571,813 $110,190,311
# 110.58M STX
# 59 First Digital USD
# FDUSD
# Buy $0.9985 0.02% 0.00% 0.01% $1,515,440,862 $3,447,393,697
# 3.45B FDUSD
# 60 Maker
# MKR
# Buy $1,808.69 0.79% 1.78% 18.93% $1,507,728,742 $77,440,807
# 42.81K MKR
# 61 Optimism
# OP
# Buy $0.8748 0.29% 11.89% 28.41% $1,449,664,970 $568,007,337
# 648.44M OP
# 62 EOS
# EOS
# Buy $0.9133 0.16% 6.16% 27.65% $1,428,861,606 $302,803,528
# 331.48M EOS
# 63 KuCoin Token
# KCS
# Buy $11.25 0.13% 0.34% 4.91% $1,407,248,856 $1,076,912
# 95.74K KCS
# 64 Sei
# SEI
# Buy $0.2609 1.33% 2.54% 26.03% $1,332,565,888 $151,330,999
# 581.97M SEI
# 65 Immutable
# IMX
# Buy $0.7236 0.46% 5.08% 29.45% $1,315,061,997 $96,972,188
# 134.21M IMX
# 66 Flare
# FLR
# Buy $0.02012 0.23% 1.63% 6.56% $1,310,118,474 $12,461,830
# 619.37M FLR
# 67 Fartcoin
# FARTCOIN
# Buy $1.30 1.25% 5.91% 19.51% $1,301,711,856 $254,091,694
# 195.67M FARTCOIN
# 68 Injective
# INJ
# Buy $12.91 0.11% 5.56% 35.03% $1,291,443,474 $180,135,164
# 13.91M INJ
# 69 Story
# IP
# Buy $4.66 0.61% 4.43% 27.97% $1,261,975,235 $101,706,780
# 21.81M IP
# 70 Virtuals Protocol
# VIRTUAL
# Buy $1.92 0.22% 2.49% 16.97% $1,253,378,413 $378,760,342
# 197.22M VIRTUAL
# 71 XDC Network
# XDC
# Buy $0.07669 0.37% 1.49% 4.56% $1,204,714,410 $44,432,863
# 580.13M XDC
# 72 Quant
# QNT
# Buy $97.24 0.04% 0.69% 13.64% $1,173,978,147 $30,177,204
# 310.45K QNT
# 73 DeXe
# DEXE
# Buy $14.02 0.34% 0.08% 3.15% $1,174,170,105 $20,041,564
# 1.43M DEXE
# 74 The Graph
# GRT
# Buy $0.1193 0.05% 0.63% 30.50% $1,172,706,323 $78,002,606
# 654.45M GRT
# 75 Curve DAO Token
# CRV
# Buy $0.7765 0.42% 0.90% 11.52% $1,042,670,771 $176,481,308
# 227.03M CRV
# 76 Theta Network
# THETA
# Buy $1.01 0.39% 6.22% 43.96% $1,010,116,103 $80,353,930
# 79.50M THETA
# 77 Lido DAO
# LDO
# Buy $1.11 0.30% 3.32% 35.12% $997,026,275 $137,128,322
# 123.42M LDO
# 78 FLOKI
# FLOKI
# Buy $0.0001036 0.92% 2.75% 34.69% $997,610,146 $194,210,628
# 1.87T FLOKI
# 79 Gala
# GALA
# Buy $0.02192 0.42% 7.10% 42.54% $972,759,310 $171,336,051
# 7.81B GALA
# 80 PayPal USD
# PYUSD
# Buy $0.9997 0.02% 0.01% 0.02% $929,881,961 $20,185,636
# 20.19M PYUSD
# 81 Four
# FORM
# Buy $2.41 0.13% 0.21% 12.23% $923,143,439 $15,427,147
# 6.37M FORM
# 82 IOTA
# IOTA
# Buy $0.2447 0.18% 1.38% 20.44% $918,041,121 $62,299,508
# 254.58M IOTA
# 83 JasmyCoin
# JASMY
# Buy $0.01857 0.44% 2.26% 15.93% $918,469,901 $65,464,766
# 3.53B JASMY
# 84 Raydium
# RAY
# Buy $3.13 0.55% 4.90% 17.25% $911,243,621 $128,661,895
# 40.83M RAY
# 85 The Sandbox
# SAND
# Buy $0.3529 0.03% 1.15% 25.82% $895,932,456 $119,085,879
# 337.09M SAND
# 86 dogwifhat
# WIF
# Buy $0.8814 0.26% 1.92% 56.71% $880,442,775 $769,745,596
# 876.96M WIF
# 87 Pudgy Penguins
# PENGU
# Buy $0.01372 0.29% 4.06% 36.95% $863,051,386 $206,190,582
# 15.08B PENGU
# 88 Ethereum Name Service
# ENS
# Buy $23.38 0.25% 1.51% 22.75% $848,809,249 $173,064,402
# 7.40M ENS
# 89 Core
# CORE
# Buy $0.8377 0.31% 0.19% 22.70% $838,601,711 $29,707,547
# 35.48M CORE
# 90 Bitcoin SV
# BSV
# Buy $41.84 0.21% 1.62% 12.99% $831,213,908 $68,247,704
# 1.63M BSV
# 91 Tether Gold
# XAUt
# Buy $3,320.39 0.04% 0.21% 2.07% $818,556,526 $23,037,159
# 6.93K XAUt
# 92 Brett (Based)
# BRETT
# Buy $0.08307 0.85% 0.20% 45.89% $823,281,949 $65,893,253
# 797.06M BRETT
# 93 Nexo
# NEXO
# Buy $1.26 0.46% 2.05% 0.79% $816,916,164 $13,043,607
# 10.33M NEXO
# 94 Walrus
# WAL
# Buy $0.6179 0.59% 1.27% 12.96% $812,863,342 $80,123,111
# 129.74M WAL
# 95 PancakeSwap
# CAKE
# Buy $2.41 1.01% 1.57% 22.59% $803,704,733 $110,780,564
# 45.53M CAKE
# 96 BitTorrent [New]
# BTT
# Buy $0.068036 0.11% 1.00% 10.75% $792,466,810 $28,478,042
# 35.47T BTT
# 97 PAX Gold
# PAXG
# Buy $3,326.36 0.05% 0.41% 2.29% $788,071,279 $32,956,614
# 9.90K PAXG
# 98 Kaia
# KAIA
# Buy $0.1238 0.74% 0.12% 7.03% $745,224,152 $25,647,421
# 207.46M KAIA
# 99 Helium
# HNT
# Buy $4.01 0.56% 1.51% 6.21% $732,529,870 $9,199,795
# 2.29M HNT
# 100 Decentraland
# MANA
# Buy $0.3662 0.05% 0.81% 22.90% $711,401,447 $74,080,485
# 202.46M MANA

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time

# %%
options = Options()
options.add_argument("--start-maximized")

# %%
# Initialize driver
driver = webdriver.Chrome(options=options)
driver.get('https://coinmarketcap.com/')
time.sleep(5)  # Allow page to load

# %%
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # Wait for new data to load
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
table = driver.find_element(By.CLASS_NAME, 'cmc-table')
rows = table.find_elements(By.TAG_NAME, 'tr')

# %%
print(f"\nTotal Rows Found: {len(rows)-1}\n")
# Out:
# Total Rows Found: 101

# %%
for row in rows[1:]:  # Skip header
    table_data = row.find_elements(By.TAG_NAME, 'td')
    try:
        rank       = table_data[1].text
        name       = table_data[2].text
        price      = table_data[3].text
        hour_change= table_data[4].text
        day_change = table_data[5].text
        seven_days = table_data[6].text
        market_cap = table_data[7].text
        volume     = table_data[8].text
        
        print(rank, name, price, hour_change, day_change, seven_days, market_cap, volume)
    except IndexError:
        continue  # Skip if structure is broken

driver.quit()
# Out:
# 1 Bitcoin
# BTC
# Buy $103,944.42 0.43% 0.04% 8.70% $2,064,670,199,544 $45,189,325,343
# 435.04K BTC
# 2 Ethereum
# ETH
# Buy $2,488.81 1.03% 3.05% 35.87% $300,475,588,805 $34,058,572,211
# 13.71M ETH
# 3 Tether
# USDT
# Buy $0.9999 0.00% 0.01% 0.02% $149,864,157,954 $98,915,779,468
# 98.90B USDT
# 4 XRP
# XRP
# Buy $2.35 0.47% 1.45% 7.14% $138,070,440,113 $5,054,009,393
# 2.14B XRP
# 5 BNB
# BNB
# Buy $655.52 0.17% 0.75% 9.95% $92,356,647,093 $2,122,967,693
# 3.23M BNB
# 6 Solana
# SOL
# Buy $173.20 0.38% 0.20% 18.86% $89,946,791,622 $4,759,101,263
# 27.47M SOL
# 7 USDC
# USDC
# Buy $0.9999 0.00% 0.00% 0.01% $60,799,275,739 $10,943,517,697
# 10.94B USDC
# 8 Dogecoin
# DOGE
# Buy $0.2309 0.89% 2.34% 32.40% $34,462,111,007 $4,060,398,316
# 17.58B DOGE
# 9 Cardano
# ADA
# Buy $0.7902 0.51% 1.37% 13.71% $27,906,336,103 $1,473,799,261
# 1.86B ADA
# 10 TRON
# TRX
# Buy $0.2608 0.71% 1.13% 5.03% $24,754,039,487 $1,036,869,975
# 3.97B TRX
# 11 Sui
# SUI
# Buy $3.95 0.39% 0.94% 22.72% $13,205,023,515 $2,413,763,981
# 610.21M SUI
# 12 Chainlink
# LINK
# Buy $16.45 0.46% 0.41% 16.98% $10,814,937,403 $667,879,016
# 40.57M LINK
# 13 Avalanche
# AVAX
# Buy $24.53 0.44% 0.87% 21.60% $10,260,304,311 $675,898,906
# 27.55M AVAX
# 14 Stellar
# XLM
# Buy $0.3030 0.79% 0.42% 12.85% $9,404,399,836 $344,288,763
# 1.13B XLM
# 32 Aptos
# APT
# Buy $5.86 0.70% 0.76% 14.68% $3,642,962,624 $293,303,225
# 49.99M APT
# 33 OKB
# OKB
# Buy $55.71 0.01% 0.23% 8.85% $3,342,707,700 $11,927,004
# 214.11K OKB
# 34 Aave
# AAVE
# Buy $219.01 1.14% 1.38% 24.30% $3,310,258,674 $375,791,708
# 1.71M AAVE
# 35 Ondo
# ONDO
# Buy $1.02 0.54% 1.32% 18.32% $3,238,848,077 $293,438,612
# 286.70M ONDO
# 36 Ethereum Classic
# ETC
# Buy $19.74 0.67% 0.65% 20.85% $2,998,338,579 $185,741,889
# 9.42M ETC
# 37 Internet Computer
# ICP
# Buy $5.57 1.09% 1.02% 20.70% $2,970,243,295 $122,784,939
# 22.14M ICP
# 38 Kaspa
# KAS
# Buy $0.1052 0.96% 1.08% 14.44% $2,753,760,425 $122,666,301
# 1.16B KAS
# 39 OFFICIAL TRUMP
# TRUMP
# Buy $13.63 0.70% 5.20% 22.56% $2,726,996,672 $1,512,257,237
# 111.23M TRUMP
# 40 GateToken
# GT
# Buy $22.09 0.27% 0.83% 2.41% $2,715,386,321 $12,889,177
# 583.36K GT
# 41 POL (prev. MATIC)
# POL
# Buy $0.2597 0.71% 0.66% 13.59% $2,706,719,102 $172,042,767
# 664.00M POL
# 42 Render
# RENDER
# Buy $5.14 1.07% 0.43% 15.59% $2,665,878,808 $129,851,293
# 25.26M RENDER
# 43 VeChain
# VET
# Buy $0.03073 0.62% 0.71% 20.22% $2,642,590,874 $79,193,001
# 2.58B VET
# 44 Cronos
# CRO
# Buy $0.09915 0.72% 3.62% 12.74% $2,634,715,030 $42,491,256
# 429.53M CRO
# 45 Mantle
# MNT
# Buy $0.7755 0.56% 0.13% 5.50% $2,609,589,774 $270,506,196
# 348.59M MNT
# 46 Ethena
# ENA
# Buy $0.3946 1.25% 3.32% 36.90% $2,297,012,714 $379,842,249
# 966.39M ENA
# 47 Arbitrum
# ARB
# Buy $0.4585 0.44% 16.87% 44.68% $2,181,042,205 $881,807,601
# 1.91B ARB
# 48 World Liberty Financial USD
# USD1
# Buy $1.00 0.01% 0.05% 0.03% $2,128,371,932 $50,799,240
# 50.79M USD1
# 49 Filecoin
# FIL
# Buy $3.13 0.40% 1.52% 19.31% $2,082,657,499 $203,399,023
# 65.09M FIL
# 50 Algorand
# ALGO
# Buy $0.2413 1.60% 0.94% 18.77% $2,075,380,292 $127,742,568
# 533.24M ALGO
# 51 Artificial Superintelligence Alliance
# FET
# Buy $0.8495 0.13% 1.63% 23.76% $2,031,071,746 $220,198,460
# 259.88M FET
# 52 Cosmos
# ATOM
# Buy $5.18 1.03% 3.85% 25.11% $2,027,849,749 $163,400,670
# 31.59M ATOM
# 53 Celestia
# TIA
# Buy $3.13 0.52% 2.68% 30.37% $1,976,060,750 $208,208,458
# 66.55M TIA
# 54 Worldcoin
# WLD
# Buy $1.26 0.99% 5.88% 33.90% $1,748,307,551 $406,024,146
# 322.67M WLD
# 55 Bonk
# BONK
# Buy $0.00002189 0.94% 3.64% 34.99% $1,731,930,192 $574,443,046
# 26.38T BONK
# 56 Sonic (prev. FTM)
# S
# Buy $0.5824 0.62% 2.36% 9.90% $1,677,517,076 $176,519,005
# 302.89M S
# 57 Jupiter
# JUP
# Buy $0.5527 0.50% 0.65% 30.82% $1,601,738,517 $112,635,552
# 205.04M JUP
# 58 Stacks
# STX
# Buy $0.9944 1.06% 4.08% 26.91% $1,516,841,994 $110,393,473
# 111.05M STX
# 59 First Digital USD
# FDUSD
# Buy $0.9982 0.02% 0.04% 0.02% $1,514,948,224 $3,472,387,661
# 3.47B FDUSD
# 60 Maker
# MKR
# Buy $1,797.94 0.22% 1.30% 18.93% $1,494,569,109 $78,014,078
# 43.54K MKR
# 61 Optimism
# OP
# Buy $0.8680 0.50% 10.97% 28.22% $1,438,459,416 $570,250,630
# 659.87M OP
# 62 EOS
# EOS
# Buy $0.9113 0.40% 6.37% 27.81% $1,425,761,345 $298,529,950
# 328.45M EOS
# 63 KuCoin Token
# KCS
# Buy $11.25 0.25% 0.21% 4.86% $1,407,080,101 $1,068,231
# 95.00K KCS
# 64 Sei
# SEI
# Buy $0.2589 1.57% 1.42% 26.03% $1,322,632,856 $152,278,691
# 589.18M SEI
# 65 Flare
# FLR
# Buy $0.02009 0.06% 1.62% 7.88% $1,308,432,727 $12,434,232
# 618.47M FLR
# 66 Immutable
# IMX
# Buy $0.7178 0.29% 4.77% 29.21% $1,304,523,024 $96,376,543
# 134.65M IMX
# 67 Fartcoin
# FARTCOIN
# Buy $1.30 1.28% 6.82% 19.27% $1,300,464,812 $253,189,254
# 195.25M FARTCOIN
# 68 Injective
# INJ
# Buy $12.79 0.83% 4.75% 34.68% $1,279,618,858 $180,278,336
# 14.07M INJ
# 69 Story
# IP
# Buy $4.62 0.05% 3.50% 27.47% $1,251,206,429 $102,193,110
# 22.09M IP
# 70 Virtuals Protocol
# VIRTUAL
# Buy $1.90 0.13% 3.32% 17.03% $1,245,943,288 $379,137,006
# 199.86M VIRTUAL
# 71 XDC Network
# XDC
# Buy $0.07596 0.42% 2.30% 3.54% $1,193,265,197 $44,548,189
# 585.42M XDC
# 72 DeXe
# DEXE
# Buy $14.04 1.38% 2.42% 2.67% $1,175,986,458 $19,599,872
# 1.40M DEXE
# 73 Quant
# QNT
# Buy $97.25 1.23% 0.43% 14.26% $1,174,094,680 $30,517,001
# 316.50K QNT
# 74 The Graph
# GRT
# Buy $0.1184 0.59% 1.20% 30.19% $1,163,997,686 $77,756,728
# 657.48M GRT
# 75 Curve DAO Token
# CRV
# Buy $0.7734 1.25% 1.52% 11.03% $1,038,435,720 $176,336,605
# 228.93M CRV
# 76 Theta Network
# THETA
# Buy $1.00 0.88% 5.40% 44.60% $1,005,145,722 $80,898,613
# 80.79M THETA
# 77 Lido DAO
# LDO
# Buy $1.10 0.94% 3.09% 35.16% $989,675,555 $136,197,898
# 124.07M LDO
# 78 FLOKI
# FLOKI
# Buy $0.0001026 1.00% 3.24% 34.71% $988,143,764 $192,748,472
# 1.88T FLOKI
# 79 Gala
# GALA
# Buy $0.02171 1.27% 6.50% 42.11% $963,401,344 $171,596,192
# 7.93B GALA
# 80 PayPal USD
# PYUSD
# Buy $0.9996 0.00% 0.01% 0.02% $929,754,585 $20,283,116
# 20.28M PYUSD
# 81 Four
# FORM
# Buy $2.41 0.07% 0.56% 12.22% $923,201,956 $15,359,137
# 6.35M FORM
# 82 JasmyCoin
# JASMY
# Buy $0.01852 1.42% 2.65% 17.09% $915,970,995 $64,959,584
# 3.51B JASMY
# 83 IOTA
# IOTA
# Buy $0.2436 0.92% 1.72% 20.57% $913,886,730 $62,127,175
# 255.57M IOTA
# 84 Raydium
# RAY
# Buy $3.11 0.77% 2.28% 17.70% $905,551,544 $126,061,583
# 40.54M RAY
# 85 The Sandbox
# SAND
# Buy $0.3510 1.17% 0.86% 26.76% $891,088,954 $118,385,629
# 338.45M SAND
# 86 dogwifhat
# WIF
# Buy $0.8779 1.56% 2.72% 56.98% $876,957,257 $753,649,208
# 867.12M WIF
# 91 Tether Gold
# XAUt
# Buy $3,319.93 0.02% 0.24% 1.99% $818,442,606 $22,958,009
# 6.91K XAUt
# 92 Nexo
# NEXO
# Buy $1.26 1.51% 1.85% 0.13% $820,086,515 $13,230,437
# 10.51M NEXO
# 93 Brett (Based)
# BRETT
# Buy $0.08245 1.61% 1.51% 45.73% $817,155,810 $65,935,829
# 804.82M BRETT
# 94 Walrus
# WAL
# Buy $0.6151 0.45% 0.17% 11.08% $809,165,467 $79,942,983
# 130.15M WAL
# 95 PancakeSwap
# CAKE
# Buy $2.41 0.21% 1.38% 22.96% $802,131,668 $110,698,356
# 46.08M CAKE
# 96 BitTorrent [New]
# BTT
# Buy $0.068005 0.03% 1.65% 10.75% $789,346,409 $28,400,761
# 35.45T BTT
# 97 PAX Gold
# PAXG
# Buy $3,326.74 0.09% 0.34% 2.23% $788,163,412 $32,823,486
# 9.86K PAXG
# 98 Kaia
# KAIA
# Buy $0.1232 1.12% 0.60% 7.23% $741,343,319 $25,629,340
# 207.93M KAIA
# 99 Helium
# HNT
# Buy $4.00 0.63% 2.01% 5.77% $730,146,948 $9,198,793
# 2.29M HNT
# 100 Flow
# FLOW
# Buy $0.4480 1.23% 0.12% 20.16% $708,557,144 $39,282,595
# 87.86M FLOW
